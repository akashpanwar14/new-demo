# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# C:\Users\Asus\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\Asus\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\Asus\anaconda3\Lib\pkgutil.py:92: NumbaPendingDeprecationWarning: The 'pycc' module is pending deprecation. Replacement technology is being developed.
#
# ...

# %%
# IPython             concurrent          menuinst            smtplib
# OpenSSL             conda               mimetypes           snappy
# PIL                 conda_build         mistune             sndhdr
# PyQt5               conda_content_trust mkl                 sniffio
# TBB                 conda_env           mkl_fft             snowballstemmer
# __future__          conda_index         mmap                socket
# __hello__           conda_libmamba_solver mmapfile            socketserver
# __phello__          conda_pack          mmsystem            socks
# _abc                conda_package_handling modulefinder        sockshandler
# _aix_support        conda_package_streaming more_itertools      sortedcontainers
# _argon2_cffi_bindings conda_token         mpmath              soupsieve
# _ast                conda_verify        msgpack             sphinx
# _asyncio            configparser        msilib              spyder
# _bisect             constantly          msvcrt              spyder_kernels
# _black_version      contextlib          multidict           sqlalchemy
# _blake2             contextvars         multipledispatch    sqlite3
# _bootsubprocess     contourpy           multiprocess        sre_compile
# _bz2                cookiecutter        multiprocessing     sre_constants
# _cffi_backend       copy                munkres             sre_parse
# _codecs             copyreg             mypy_extensions     ssl
# _codecs_cn          cpuinfo             nacl                sspi
# _codecs_hk          crypt               navigator_updater   sspicon
# _codecs_iso2022     cryptography        nbclassic           stack_data
# _codecs_jp          cssselect           nbclient            stat
# _codecs_kr          csv                 nbconvert           statistics
# _codecs_tw          ctypes              nbformat            statsmodels
# _collections        curl                nest_asyncio        string
# _collections_abc    curses              netbios             stringprep
# _compat_pickle      cwp                 netrc               struct
# _compression        cycler              networkx            subprocess
# _contextvars        cytoolz             nltk                sunau
# _csv                daal4py             nntplib             sympy
# _ctypes             dask                notebook            symtable
# _ctypes_test        dataclasses         notebook_shim       sys
# _datetime           datasets            nt                  sysconfig
# _decimal            datashader          ntpath              tables
# _distutils_hack     datashape           ntsecuritycon       tabnanny
# _elementtree        datetime            nturl2path          tabulate
# _functools          dateutil            numba               tarfile
# _hashlib            dbi                 numbergen           tbb
# _heapq              dbm                 numbers             tblib
# _imp                dde                 numexpr             telnetlib
# _io                 debugpy             numpy               tempfile
# _json               decimal             numpydoc            tenacity
# _locale             decorator           odbc                terminado
# _lsprof             defusedxml          onedal              test
# _lzma               diff_match_patch    opcode              test_pycosat
# _markupbase         difflib             openpyxl            tests
# _md5                dill                operator            text_unidecode
# _msi                dis                 optparse            textdistance
# _multibytecodec     distributed         os                  textwrap
# _multiprocess       distutils           packaging           this
# _multiprocessing    docstring_to_markdown pandas              threading
# _nsis               doctest             pandocfilters       threadpoolctl
# _opcode             docutils            panel               three_merge
# _operator           dotenv              param               tifffile
# _osx_support        email               paramiko            time
# _overlapped         encodings           parsel              timeit
# _pickle             ensurepip           parso               timer
# _plotly_future_     entrypoints         partd               tinycss2
# _plotly_utils       enum                past                tkinter
# _py_abc             erfa                pathlib             tldextract
# _pydecimal          errno               pathspec            tlz
# _pyio               et_xmlfile          patsy               token
# _pyrsistent_version executing           pbkdf2              tokenize
# _pytest             fastjsonschema      pdb                 tokenizers
# _queue              faulthandler        pep8                toml
# _random             filecmp             perfmon             tomlkit
# _sha1               fileinput           pexpect             tomllib
# _sha256             filelock            pickle              toolz
# _sha3               flake8              pickleshare         tornado
# _sha512             flask               pickletools         tqdm
# _signal             fnmatch             pip                 trace
# _sitebuiltins       fontTools           pipes               traceback
# _socket             fractions           pkce                tracemalloc
# _sqlite3            frozenlist          pkg_resources       traitlets
# _sre                fsspec              pkginfo             transformers
# _ssl                ftplib              pkgutil             tty
# _stat               functools           platform            turtle
# _statistics         future              platformdirs        turtledemo
# _string             gc                  plistlib            twisted
# _strptime           genericpath         plotly              types
# _struct             gensim              pluggy              typing
# _symtable           getopt              ply                 typing_extensions
# _system_path        getpass             poplib              tzdata
# _testbuffer         gettext             posixpath           uc_micro
# _testcapi           glob                poyo                ujson
# _testconsole        glob2               pprint              unicodedata
# _testimportmultiple graphlib            profile             unidecode
# _testinternalcapi   greenlet            prometheus_client   unittest
# _testmultiphase     gzip                prompt_toolkit      urllib
# _thread             h5py                protego             urllib3
# _threading_local    hashlib             pstats              uu
# _tkinter            heapdict            psutil              uuid
# _tokenize           heapq               pty                 venv
# _tracemalloc        hmac                ptyprocess          w3lib
# _typing             holoviews           pure_eval           warnings
# _uuid               html                pvectorc            watchdog
# _warnings           http                py                  wave
# _weakref            huggingface_hub     py_compile          wcwidth
# _weakrefset         hvplot              pyarrow             weakref
# _win32sysloader     hyperlink           pyasn1              webbrowser
# _winapi             idlelib             pyasn1_modules      webencodings
# _winxptheme         idna                pyclbr              websocket
# _xxsubinterpreters  imagecodecs         pycodestyle         werkzeug
# _yaml               imageio             pycosat             whatthepatch
# _zoneinfo           imagesize           pycparser           wheel
# abc                 imaplib             pyct                widgetsnbextension
# adodbapi            imblearn            pycurl              wifi
# afxres              imghdr              pydantic            win2kras
# aifc                imp                 pydispatch          win32api
# aiobotocore         importlib           pydoc               win32clipboard
# aiofiles            importlib_metadata  pydoc_data          win32com
# aiohttp             incremental         pydocstyle          win32con
# aioitertools        inflection          pyexpat             win32console
# aiosignal           iniconfig           pyflakes            win32cred
# aiosqlite           inspect             pygments            win32crypt
# alabaster           intake              pylab               win32cryptcon
# anaconda_anon_usage intervaltree        pylint              win32ctypes
# anaconda_catalogs   io                  pylint_venv         win32event
# anaconda_cloud_auth ipaddress           pyls_spyder         win32evtlog
# anaconda_navigator  ipykernel           pylsp               win32evtlogutil
# anaconda_project    ipykernel_launcher  pylsp_black         win32file
# antigravity         ipython_genutils    pylsp_jsonrpc       win32gui
# anyio               ipywidgets          pyodbc              win32gui_struct
# appdirs             isapi               pyparsing           win32help
# argon2              isort               pyrsistent          win32inet
# argparse            isympy              pytest              win32inetcon
# array               itemadapter         pythoncom           win32job
# arrow               itemloaders         pythonjsonlogger    win32lz
# ast                 itertools           pytoolconfig        win32net
# astroid             itsdangerous        pytz                win32netcon
# astropy             jedi                pyviz_comms         win32pdh
# asttokens           jellyfish           pywifi              win32pdhquery
# async_timeout       jinja2              pywin               win32pdhutil
# asynchat            jinja2_time         pywin32_bootstrap   win32pipe
# asyncio             jmespath            pywin32_testutil    win32print
# asyncore            joblib              pywintypes          win32process
# atexit              json                pywt                win32profile
# atomicwrites        json5               qdarkstyle          win32ras
# attr                jsonpatch           qstylizer           win32rcparser
# attrs               jsonpointer         qtawesome           win32security
# audioop             jsonschema          qtconsole           win32service
# automat             jupyter             qtpy                win32serviceutil
# autopep8            jupyter_client      queue               win32timezone
# babel               jupyter_console     queuelib            win32trace
# backcall            jupyter_core        quopri              win32traceutil
# backports           jupyter_events      random              win32transaction
# base64              jupyter_server      rasutil             win32ts
# bcrypt              jupyter_server_fileid re                  win32ui
# bdb                 jupyter_server_ydoc regcheck            win32uiole
# binaryornot         jupyter_ydoc        regex               win32verstamp
# binascii            jupyterlab          regutil             win32wnet
# binstar_client      jupyterlab_plotly   repo_cli            win_inet_pton
# bisect              jupyterlab_pygments reprlib             winerror
# black               jupyterlab_server   requests            winioctlcon
# blackd              jupyterlab_widgets  requests_file       winnt
# bleach              jwt                 requests_toolbelt   winperf
# blib2to3            kaleido             responses           winpty
# bokeh               keyring             rfc3339_validator   winreg
# boltons             keyword             rfc3986_validator   winsound
# botocore            kiwisolver          rlcompleter         winxpgui
# bottleneck          lazy_loader         rope                winxptheme
# brotli              lazy_object_proxy   rtree               wrapt
# bs4                 lib2to3             ruamel_yaml         wsgiref
# builtins            libarchive          runpy               xarray
# bz2                 libfuturize         s3fs                xdrlib
# cProfile            libmambapy          safetensors         xlwings
# calendar            libpasteurize       sched               xml
# certifi             lief                scipy               xmlrpc
# cffi                linecache           scrapy              xxhash
# cgi                 linkify_it          seaborn             xxlimited
# cgitb               llvmlite            secrets             xxlimited_35
# chardet             lmdb                select              xxsubtype
# charset_normalizer  locale              selectors           xyzservices
# chunk               locket              send2trash          y_py
# click               logging             service_identity    yaml
# cloudpickle         lxml                servicemanager      yapf
# clyent              lz4                 setuptools          yapftests
# cmath               lzma                shelve              yarl
# cmd                 mailbox             shlex               ypy_websocket
# code                mailcap             shutil              zict
# codecs              markdown            signal              zipapp
# codeop              markdown_it         sipbuild            zipfile
# collections         markupsafe          site                zipimport
# colorama            marshal             six                 zipp
# colorcet            math                skimage             zlib
# colorsys            matplotlib          sklearn             zmq
# comm                matplotlib_inline   sklearnex           zoneinfo
# commctrl            mccabe              slugify             zope
# compileall          mdit_py_plugins     smart_open          zstandard
# comtypes            mdurl               smtpd               

# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# ​

# %%
import os
i=1
while i<26:
  os.mkdir("C:\\COLLEGE BOOKS\\new module\\chapter {i}")
  i+=1
